# %%
import math
import matplotlib.pyplot as plt

#print(math.sin(math.pi))

fig, ax = plt.subplots(2,1)

ax[0].plot([1,2,3],[1,2,3])
ax[1].plot([1,2,3],[1,3,5])

plt.show()

# %% [markdown]
# Text link [Title](#Title)

# %% [markdown]
# # Title
